# %%
# 10) Data Visualization III
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a boxplot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Step 1: List down the features and their types
print("Feature Types:")
print(df.dtypes)
# Out:
# Feature Types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# Step 2: Create histograms for each feature
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Step 3: Create boxplot for each feature
plt.figure(figsize=(10, 8))
sns.boxplot(data=df.drop('species', axis=1), orient="h")
plt.tight_layout()
plt.show()

# %%
# Expected Outputs:
# Feature Types: You will get a listing of the data types for each feature, such as numeric (float64) for the sepal and petal dimensions and nominal (object) for the species column.

# Histograms: A set of histograms for each feature will be displayed, showing how the data is distributed.

# Boxplots: Boxplots for each feature will highlight the median, quartiles, and outliers in the data.

# Inference from the Dataset:
# Features and Types:

# sepal_length, sepal_width, petal_length, petal_width: Numeric features (float).

# species: Nominal feature (categorical).

# Distributions:

# Histograms will show whether the data is normally distributed, skewed, or has any noticeable patterns.

# Outliers:

# Boxplots will show if any features have extreme values (outliers), which can be visually identified as points outside the whiskers.
